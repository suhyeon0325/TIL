# %% [markdown]
# <a href="https://colab.research.google.com/github/suhyeon0325/multicamp34/blob/main/Pandas_240108%EC%98%A4%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 통합하기

# %% [markdown]
# 1.   항목 추가
#
# 1.   항목 추가
# 2.   항목 추가
#
#
# 2.   항목 추가

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({
    'Class1': [95, 92, 98, 100],
    'Class2': [91, 93, 97, 99]
})

df2= pd.DataFrame({
    'Class1': [87, 89],
    'Class2': [85, 90]
})

df2
# Out:
#    Class1  Class2
# 0      87      85
# 1      89      90

# %%
# df1.append(df2)  # 에러 발생 # pandas 버전 1.4.0 이후로 지원 안함. concat() 사용 권장

# %%
result = pd.concat([df1, df2])
result
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      97
# 3     100      99
# 0      87      85
# 1      89      90

# %%
df3 = pd.DataFrame({
    'Class1' : [96, 83]
})

pd.concat([result, df3], ignore_index=True)
# Out:
#    Class1  Class2
# 0      95    91.0
# 1      92    93.0
# 2      98    97.0
# 3     100    99.0
# 4      87    85.0
# 5      89    90.0
# 6      96     NaN
# 7      83     NaN

# %% [markdown]
# ### 가로 방향으로 통합하기
# - pd.concat(): 세로 방향으로 통합하기

# %%
df4 = pd.DataFrame({
    'Class3' :[93, 91, 95, 98]
})
df1.join(df4)
# Out:
#    Class1  Class2  Class3
# 0      95      91      93
# 1      92      93      91
# 2      98      97      95
# 3     100      99      98

# %%
index_label = ['a','b','c','d']
df1a = pd.DataFrame({'Class1': [95, 92, 98, 100],
                    'Class2': [91, 93, 97, 99]}, index= index_label)
df4a = pd.DataFrame({'Class3': [93, 91, 95, 98]}, index=index_label)

df1a.join(df4a)
# Out:
#    Class1  Class2  Class3
# a      95      91      93
# b      92      93      91
# c      98      97      95
# d     100      99      98

# %%
index_label = ['a','b','c','d']
df1a = pd.DataFrame({'Class1': [95, 92, 98, 100],
                    'Class2': [91, 93, 97, 99]})
df4a = pd.DataFrame({'Class3': [93, 91, 95, 98]}, index=index_label)

df1a.join(df4a)
# 인덱스 번호가 불일치한 상태에서 join을 하면 작동이 제대로 되지 않는다.
# join을 할 때는 index가 같은지 체크해보자!
# Out:
#    Class1  Class2  Class3
# 0      95      91     NaN
# 1      92      93     NaN
# 2      98      97     NaN
# 3     100      99     NaN

# %%
df4.index == df1a.index
# Out:
# array([ True,  True,  True,  True])

# %%
df_A_B = pd.DataFrame({'판매월': ['1월', '2월', '3월', '4월'],
                       '제품A': [100, 150, 200, 130],
                       '제품B': [90, 110, 140, 170]})

df_C_D = pd.DataFrame({'판매월': ['1월', '2월', '3월', '4월'],
                       '제품C': [112, 141, 203, 134],
                       '제품D': [90, 110, 140, 170]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-413b988d3659> in <cell line: 1>()
# ----> 1 df_A_B = pd.DataFrame({'판매월': ['1월', '2월', '3월', '4월'],
#       2                        '제품A': [100, 150, 200, 130],
#       3                        '제품B': [90, 110, 140, 170]})
#       4
#       5 df_C_D = pd.DataFrame({'판매월': ['1월', '2월', '3월', '4월'],
#
# NameError: name 'pd' is not defined

# %%
df_C_D
# Out:
#   판매월  제품C  제품D
# 0  1월  112   90
# 1  2월  141  110
# 2  3월  203  140
# 3  4월  134  170

# %%
df_A_B.merge(df_C_D)
# Out:
#   판매월  제품A  제품B  제품C  제품D
# 0  1월  100   90  112   90
# 1  2월  150  110  141  110
# 2  3월  200  140  203  140
# 3  4월  130  170  134  170

# %%
df_A_B.join(df_C_D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aad50da42268> in <cell line: 1>()
# ----> 1 df_A_B.join(df_C_D)
#
# NameError: name 'df_A_B' is not defined

# %%
df_left = pd.DataFrame({'key':['A','B','C'], 'left': [1, 2, 3]})
df_right = pd.DataFrame({'key':['A','B','D'], 'right': [4, 5, 6]})

# %%
# 274
df_left.merge(df_right, how='left', on = 'key')
# Out:
#   key  left  right
# 0   A     1    4.0
# 1   B     2    5.0
# 2   C     3    NaN

# %%
df_left.merge(df_right, how='right', on='key')
# Out:
#   key  left  right
# 0   A   1.0      4
# 1   B   2.0      5
# 2   D   NaN      6

# %%
df_left.merge(df_right, how='outer', on='key')  # Full Join
# Out:
#   key  left  right
# 0   A   1.0    4.0
# 1   B   2.0    5.0
# 2   C   3.0    NaN
# 3   D   NaN    6.0

# %%
df_left.merge(df_right, how='inner', on='key')  # 교집합
# Out:
#   key  left  right
# 0   A     1      4
# 1   B     2      5

# %%
df_A_B = pd.DataFrame({'판매월':['1월', '2월', '3월', '4월'], '제품A': [100, 150, 200, 130], '제품B': [90, 110, 140, 170]})
df_C_D = pd.DataFrame({'판매월':['1월', '2월', '3월', '4월'], '제품D': [90, 110, 140, 170], '제품B': [90, 110, 140, 170]})

print(df_A_B)
print(df_C_D)
# Out:
#   판매월  제품A  제품B
# 0  1월  100   90
# 1  2월  150  110
# 2  3월  200  140
# 3  4월  130  170
#   판매월  제품D  제품B
# 0  1월   90   90
# 1  2월  110  110
# 2  3월  140  140
# 3  4월  170  170

# %%
df_A_B.merge(df_C_D)
# Out:
#   판매월  제품A  제품B  제품D
# 0  1월  100   90   90
# 1  2월  150  110  110
# 2  3월  200  140  140
# 3  4월  130  170  170
